# %%
import plasma_fusion_simulation_tools.simulation_dashboard.sim_watcher.src.get_slurm_job_info as slurmy

from datetime import datetime, timedelta
#  get_slurm_job_df_info, load_existing_job_info

# %%
start_date = datetime.now() - timedelta(days=4)

job_df = slurmy.get_slurm_job_df_info(start_date=start_date, verbose=True)

print(job_df)
# Out:
# Fetching data from: /global/homes/j/joeschm/tools/plasma_fusion_simulation_tools/simulation_dashboard/sim_watcher/data/slurm_jobs_data.csv
# Fetching additional data after CSV's latest record.
# Start date: 2024-02-28 00:00:00 /// End date: 2024-02-29 00:00:00 /// Day Chunk Size: 1
# sacct -u joeschm --starttime=2024-02-28 --endtime=2024-02-29 -X --format=JobID,Submit,Start,End,NNodes,QOS,State,Elapsed,User --parsable2
# 10 entries in the slurm job list.
# Data saved to /global/homes/j/joeschm/tools/plasma_fusion_simulation_tools/simulation_dashboard/sim_watcher/data/slurm_jobs_data.csv
#        JobID              Submit               Start                 End  \
# 0   22300146 2024-02-28 16:26:23 2024-02-28 16:29:49 2024-02-28 16:40:03
# 1   22298305 2024-02-28 14:48:12 2024-02-28 15:22:19 2024-02-28 15:43:12
# 2   22298220 2024-02-28 14:44:59 2024-02-28 15:19:28 2024-02-28 15:49:39
# 3   22297873 2024-02-28 14:40:56 2024-02-28 15:03:22 2024-02-28 15:22:04
# ...
