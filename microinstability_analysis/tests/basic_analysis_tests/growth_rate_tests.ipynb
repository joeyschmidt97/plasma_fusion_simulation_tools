# %%
import os

import plasma_fusion_simulation_tools.microinstability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_plotting as GR

# %%
PE_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top'
NE_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top'
OM_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top'

# %%
kymin_129038_OM = os.path.join(OM_129038, 'kymin_scan')
kymin_129038_OM_V2 = os.path.join(OM_129038, 'convergence_check', 'kymin_scan_nz0_256')

path_test = [kymin_129038_OM, kymin_129038_OM_V2]

criteria = ['40<=kymin<=60']
# criteria = []

print(kymin_129038_OM)
GR.gamma_omega_plot(path_test, criteria, verbose=True)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan/scanfiles0000/omega_0008']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/convergence_check/kymin_scan_nz0_256/scanfiles0002/omega_0003']

# %%
path_test = [kymin_129038_OM, kymin_129038_OM_V2]

criteria = ['kymin < 10']

print(kymin_129038_OM)
GR.gamma_omega_plot(path_test, criteria, verbose=True)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan/scanfiles0000/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan/scanfiles0000/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan/scanfiles0000/omega_0004'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan/scanfiles0000/omega_0005'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan/scanfiles0001/omega_0002']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/convergence_check/kymin_scan_nz0_256/scanfiles0000/omega_0002'
# ...

# %% [markdown]
# # 129015

# %%
NE_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top'
PE_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top'
OM_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top'

# %% [markdown]
# ### 129015 - NE

# %%
kymin_129015_NE = os.path.join(NE_129015, 'kymin_scan')
kymin_129015_NE_df = growth_freq_dataframe(kymin_129015_NE)

criteria = []

print(kymin_129015_NE)
gamma_omega_plot(kymin_129015_NE, criteria)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 kymin_129015_NE = os.path.join(NE_129015, 'kymin_scan')
# ----> 2 kymin_129015_NE_df = growth_freq_dataframe(kymin_129015_NE)
#       4 criteria = []
#       6 print(kymin_129015_NE)
#
# NameError: name 'growth_freq_dataframe' is not defined

# %% [markdown]
# ### 129015 - PE

# %%
kymin_129015_PE = os.path.join(PE_129015, 'kymin_scan')

criteria = []

print(kymin_129015_PE)
gamma_omega_plot(kymin_129015_PE, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kymin_scan

# %% [markdown]
# ### 129015 - OM

# %%
kymin_129015_OM = os.path.join(OM_129015, 'kymin_scan')

criteria = []

print(kymin_129015_OM)
gamma_omega_plot(kymin_129015_OM, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan

# %% [markdown]
# # 129038

# %%
PE_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top'
NE_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top'
OM_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top'

# %% [markdown]
# ### 129038 - PE

# %%
kymin_129038_PE = os.path.join(PE_129038, 'kymin_scan')

criteria = []

print(kymin_129038_PE)
gamma_omega_plot(kymin_129038_PE, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/kymin_scan
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 criteria = []
#       5 print(kymin_129038_PE)
# ----> 6 gamma_omega_plot(kymin_129038_PE, criteria)
#
# NameError: name 'gamma_omega_plot' is not defined

# %% [markdown]
# ### 129038 - NE

# %%
kymin_129038_NE = os.path.join(NE_129038, 'kymin_scan')

criteria = []

print(kymin_129038_NE)
gamma_omega_plot(kymin_129038_NE, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan

# %% [markdown]
# ### 129038 - OM

# %%
kymin_129038_OM = os.path.join(OM_129038, 'kymin_scan')

criteria = []

print(kymin_129038_OM)
gamma_omega_plot(kymin_129038_OM, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan

# %% [markdown]
# # Testing Percent difference plotting

# %%
# kymin_129038_OM = os.path.join(OM_129038, 'kymin_scan')
# kymin_129038_OM_V2 = os.path.join(OM_129038, 'convergence_check', 'kymin_scan_nz0_256')

# path_test = [kymin_129038_OM, kymin_129038_OM_V2]

# criteria = []

# print(kymin_129038_OM)
# GR.gamma_omega_plot(path_test, criteria, verbose=True)
